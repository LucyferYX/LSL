# %%
def gen():
    for i in range(3):
        yield i*i

g = gen()
a = list(g)
b = list(g)

print(a,b)
# Out:
# [0, 1, 4] []

# %%
import copy

a = [[1,2], [3,4]]

b = copy.copy(a)

b[0].append(99)

print(a)
# Out:
# [[1, 2], [3, 4]]
# [[1, 2, 99], [3, 4]]

# %%
import pandas as pd

df = pd.DataFrame({'g':['A','A','B'],
'x':[10,30,20]})
s = df.groupby('g')['x'].transform('mean')
print(list(s))
# Out:
# [20.0, 20.0, 20.0]

# %%
d = {'a':1}
print(d.get('b', 5) + d.get('a'))
# Out:
# 6

# %%
items = ["apple", "Banana", "pear",
"Avocado"]

print(sorted(items, key=str.lower) [0])
# Out:
# apple

# %%
pairs = [(1,2),(3,4)]
a = [x+y for x,y in pairs]
print(a)
# Out:
# [3, 7]

# %%
preds = []
true = [10, 8, 6]
for y_true in true:

    y_pred = y_true - 1

    preds.append(abs(y_true - y_pred))

print(sum(preds))
# Out:
# 3
